# %% [markdown]
# # Cheatsheet examples

# %%
from gym_cas import *

# %% [markdown]
# ## B1. Tal- og bogstavregning

# %%
expand( (x+3) ** 2)
# Out:
# x**2 + 6*x + 9

# %%
factor( x**2 + 6*x + 9 )
# Out:
# (x + 3)**2

# %% [markdown]
# ## B2. Ligninger og uligheder

# %%
solve(x**2+3.*x-2)
# Out:
# [-3.56155281280883, 0.561552812808830]

# %%
solve([a+b-2,a-b-4])
# Out:
# {a: 3, b: -1}

# %%
nsolve(2*sin(x**2)-x,0.5)
# Out:
# 0.505482272339305

# %% [markdown]
# ## B3. Geometri og trigonometri

# %%
Sin(90)
# Out:
# 1.00000000000000

# %%
aSin(1)
# Out:
# 90.0000000000000

# %% [markdown]
# ## B4. Analytisk Plangeometri

# %%
plot_list([1,2,3],[6,5,6],is_point=True)

# %%
plot(3*x+4)

# %%
plot_implicit(x**2 + y**2 - 1,xlim=(-1,1),ylim=(-1,1), n=200)

# %%
plot_geometry(Circle(Point(0, 0), 1))

# %%
p1 = plot_list([1,2,3],[6,5,6],xlim=(-5,5),ylim=(-2,8),is_point=True,show=False)
p2 = plot(3*x+4,show=False)
p3 = plot_implicit(x**2 + y**2 - 1,xlim=(-1,1),ylim=(-1,1),show=False)
p4 = plot_geometry(Circle(Point(0, 0), 1),show=False)
p = p1 + p2 + p3 + p4   # type: ignore
p.show()

# %% [markdown]
# ## B5. Vektorer

# %%
a = Matrix([30,70])
a
# Out:
# Matrix([
# [30],
# [70]])

# %%
a.dot(Matrix([6,0]))
# Out:
# 180

# %%
plot_vector(a)

# %%
plot_vector((0,1),a)

# %%
plot_vector([a,Matrix([6,0])])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plot_vector([a,Matrix([6,0])])
#
# File d:\Programs\Python311\Lib\site-packages\gym_cas\vector.py:259, in plot_vector(*args, **kwargs)
#     256 else:
#     257     raise TypeError(f"plot_vector() expects 1 or 2 arguments ({len(args)} were given)")
# --> 259 limits = calc_limits(v, s)
#     260 for lim in limits:
#     261     kwargs.setdefault(lim, limits[lim])
#
# File d:\Programs\Python311\Lib\site-packages\gym_cas\vector.py:166, in calc_limits(v, s)
#     163     s = [s]
#     165 for d in range(len(v[0])):
# --> 166     d_min = v[0][d] + s[0][d] if v[0][d] + s[0][d] < s[0][d] else s[0][d]
#     167     d_max = v[0][d] + s[0][d] if v[0][d] + s[0][d] > s[0][d] else s[0][d]
#     168     for i in range(len(v)):
#
# ...
