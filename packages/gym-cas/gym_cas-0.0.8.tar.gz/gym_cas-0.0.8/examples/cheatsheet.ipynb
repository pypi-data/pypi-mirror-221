# %% [markdown]
# # Cheatsheet examples

# %%
from gym_cas import *

# %% [markdown]
# ## B1. Tal- og bogstavregning

# %%
expand( (x+3) ** 2)
# Out:
# x**2 + 6*x + 9

# %%
factor( x**2 + 6*x + 9 )
# Out:
# (x + 3)**2

# %% [markdown]
# ## B2. Ligninger og uligheder

# %%
solve(x**2+3.*x-2)
# Out:
# [-3.56155281280883, 0.561552812808830]

# %%
solve([a+b-2,a-b-4])
# Out:
# {a: 3, b: -1}

# %%
nsolve(2*sin(x**2)-x,0.5)
# Out:
# 0.505482272339305

# %% [markdown]
# ## B3. Geometri og trigonometri

# %%
Sin(90)
# Out:
# 1.00000000000000

# %%
aSin(1)
# Out:
# 90.0000000000000

# %% [markdown]
# ## B4. Analytisk Plangeometri

# %%
plot_list([1,2,3],[6,5,6],is_point=True)

# %%
plot(3*x+4)

# %%
plot_implicit(x**2 + y**2 - 1,xlim=(-1,1),ylim=(-1,1), n=200)

# %%
plot_geometry(Circle(Point(0, 0), 1))

# %%
p1 = plot_list([1,2,3],[6,5,6],xlim=(-5,5),ylim=(-2,8),is_point=True,show=False)
p2 = plot(3*x+4,show=False)
p3 = plot_implicit(x**2 + y**2 - 1,xlim=(-1,1),ylim=(-1,1),show=False)
p4 = plot_geometry(Circle(Point(0, 0), 1),show=False)
p = p1 + p2 + p3 + p4   # type: ignore
p.show()

# %% [markdown]
# ## B5. Vektorer

# %%
a = Matrix([3,7])
a
# Out:
# Matrix([
# [3],
# [7]])

# %%
a.dot(Matrix([6,0]))
# Out:
# 18

# %%
plot_vector(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_vector(a)
#
# File d:\Programs\Python311\Lib\site-packages\spb\vectors.py:775, in plot_vector(*args, **kwargs)
#     772 labels = kwargs.pop("label", [])
#     773 rendering_kw = kwargs.pop("rendering_kw", None)
# --> 775 series = _build_series(*args, **kwargs)
#     776 _set_labels(series, labels, rendering_kw)
#     778 if all([isinstance(s, (Vector2DSeries, ContourSeries)) for s in series]):
#
# File d:\Programs\Python311\Lib\site-packages\spb\vectors.py:31, in _build_series(*args, **kwargs)
#      29 is_vec_lambda_function = False
#      30 for a in args:
# ---> 31     split_expr, ranges, s = _series(a[0], *a[1:-1], label=a[-1], **kwargs)
#      32     all_ranges.append(ranges)
#      33     if isinstance(s, (list, tuple)):
#
# File d:\Programs\Python311\Lib\site-packages\spb\vectors.py:125, in _series(expr, label, *ranges, **kwargs)
#     123 missing = fs.difference(fs_ranges)
#     124 if not missing:
# --> 125     raise ValueError(
#     126         "In a 2D vector field, 2 unique ranges are expected. "
#     127         + "Unfortunately, it is not possible to deduce them from "
#     128         + "the provided vector.\n"
#     129         + "Vector: {}, Free symbols: {}\n".format(expr, fs)
#     130         + "Provided ranges: {}".format(ranges)
#     131     )
#     132 ranges = list(ranges)
#     133 for m in missing:
#
# ValueError: In a 2D vector field, 2 unique ranges are expected. Unfortunately, it is not possible to deduce them from the provided vector.
# Vector: Matrix([[3], [7]]), Free symbols: set()
# Provided ranges: ()
